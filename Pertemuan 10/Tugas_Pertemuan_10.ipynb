# %% [markdown]
# Tuple

# %%
# 1. Tuples:
# a. Buat sebuah tuple bernama mahasiswa yang berisi data diri anda dengan 3 nilai ("Nama", "Nim", "Prodi")
mahasiswa = ("Euaggelion", "2505060049", "Teknologi Informasi")

# c. Tampilkan data NIM dan Prodi
print("NIM:", mahasiswa_list[1])
print("Prodi", mahasiswa_list[2])
# Out:
# NIM: 2505060049
# Prodi Teknologi Informasi dan Elektro

# %% [markdown]
# Dictionary

# %%
# a. Buat dictionary keranjang dengan data: {"apel": 5000, "pisang": 3000, "jeruk": 7000,
# "anggur": 15000}
# b. Gunakan perulangan untuk menghitung total harga semua barang
# c. Tampilkan setiap barang dan harganya dalam format: ex: "Harga apel: Rp 5000"
# d. Tampilkan harga total belanja

keranjang = {
    "apel": 5000,
    "pisang": 3000,
    "jeruk": 7000,
    "anggur": 15000,
}

total = 0

for buah, harga in keranjang.items():
  print(f"harga {buah}: {harga}")
  total += harga
print(f"harga total: {total}")
# Out:
# harga apel: 5000
# harga pisang: 3000
# harga jeruk: 7000
# harga anggur: 15000
# harga total: 30000
